# %% [markdown]
# # Text Classification - BERT
#
# **Notebook:** 05_classification_bert.ipynb
#
# **Sections:**
# 1. Load BERT-base
# 2. Prepare AG News dataset (4-class classification)
# 3. Add sequence classification head
# 4. Configure class weights for imbalanced data
# 5. Training with early stopping
# 6. Evaluation: Accuracy, F1, Precision, Recall
# 7. Confusion matrix analysis
# 8. Error analysis
# 9. Save classifier

# %% [markdown]
# ## 1. Load BERT-base

# %%
# TODO: Implement Load BERT-base

pass

# %% [markdown]
# ## 2. Prepare AG News dataset (4-class classification)

# %%
# TODO: Implement Prepare AG News dataset (4-class classification)

pass

# %% [markdown]
# ## 3. Add sequence classification head

# %%
# TODO: Implement Add sequence classification head

pass

# %% [markdown]
# ## 4. Configure class weights for imbalanced data

# %%
# TODO: Implement Configure class weights for imbalanced data

pass

# %% [markdown]
# ## 5. Training with early stopping

# %%
# TODO: Implement Training with early stopping

pass

# %% [markdown]
# ## 6. Evaluation: Accuracy, F1, Precision, Recall

# %%
# TODO: Implement Evaluation: Accuracy, F1, Precision, Recall

pass

# %% [markdown]
# ## 7. Confusion matrix analysis

# %%
# TODO: Implement Confusion matrix analysis

pass

# %% [markdown]
# ## 8. Error analysis

# %%
# TODO: Implement Error analysis

pass

# %% [markdown]
# ## 9. Save classifier

# %%
# TODO: Implement Save classifier

pass
